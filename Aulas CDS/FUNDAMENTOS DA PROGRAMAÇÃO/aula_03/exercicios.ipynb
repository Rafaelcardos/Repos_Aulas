# %% [markdown]
# # Exercício 1.0

# %% [markdown]
# ## Problema

# %% [markdown]
# Considere um arquivo CSV com os seguintes dados de todas as copas do mundo até o ano de 2014. As informações do arquivo são:
#
# * Year - Ano da copa
# * Country - País sede
# * Winner - Campeão
# * Runners-Up - Vice-Campeão
# * Third - Terceiro lugar
# * Fourth - Quarto Lugar
# * GoalsScored - Total de Gols
# * QualifiedTeams - Quantidade de Times
# * MatchesPlayed - Quantidade de Jogos
# * Attendance - Público Total
#
# Efetue a leitura desse arquivo, sem a utilização de módulos externos (Pandas), e crie um arquivo de saída com as seguintes informações (uma informação por linha):
#
#     * Soma de público das copas com anos final 0 (1930, 1950, etc)
#     * Quantidade total de gols entre as copas de 1954 e 1990, inclusive
#     * Média de público
#     * Média de gols por partida
# * Quantidade de vezes em que o país sede foi campeão
# * Quantidade de vezes em que o time do Brasil ficou entre uma das 4 primeiras posições
# * Ano das edições em que o time da França finalizou em terceiro lugar
# * Quantidade de vitórias por país, ordenada de forma crescente por número de títulos

# %% [markdown]
# ## Análise

# %% [markdown]
#    Coloque a sua análise aqui

# %% [markdown]
# ## Implicações / Proposições / Afirmações

# %% [markdown]
# Coloque as implicações / Proposições / Afirmações aqui

# %% [markdown]
# ## Resolução e Resposta

# %%
# Resolução e Resposta Aqui
import csv #importa a biblioteca


publicofinal0 = 0
golstotal5490 = 0
publicototal = 0
golstotal = 0
quantidadecopas = 0
totalpartidas = 0
sedecampeao = 0
brasil4 = 0
franca3 = 0



with open('G:/Meu Drive/jupyter/Aulas CDS/FUNDAMENTOS DA PROGRAMAÇÃO/aula_03/csv/world_cups.csv') as file:
    reader= csv.reader(file, delimiter=",")
    next(reader) # pular cabeçalho
    
    
    for linha in reader:
        print(linha)
        golstotal += int(linha[6]) #incrementa a qtde de gols
        totalpartidas += int(linha[-2]) # incrementa a qtdade de partidas
      
    
    if (linha[0].endswith('0')):
        publicofinal0 += int(linha[-1].replace('.',''))
        
    if (1954 <= int(linha[0]) and int(linha[0]) <= 1990):
        golstotal5490 = golstotal5490 + int(linha[6].replace('.',''))
       
       
        
        
        
        
        
        
        
        
print(f'Total de gols: {golstotal}')
print(f'Total de Partidas: {totalpartidas}')
print(f'média de gols por partida: {round(golstotal/totalpartidas,2)}')  #round arredonda para 2 casas decimais
print(f'Soma de publico nas copas final 0: {publicofinal0}')
print(f'Gols total entre 1954 e 1990: {golstotal5490}')
#print(f'média de gols por partida: {round(totalpartidas/,2)}')


    

        
        

      
   
        
        
        
        
        
        
        
        
        
csv_file.close()
# Out:
# ['1930', 'Uruguay', 'Uruguay', 'Argentina', 'USA', 'Yugoslavia', '70', '13', '18', '590.549']
# ['1934', 'Italy', 'Italy', 'Czechoslovakia', 'Germany', 'Austria', '70', '16', '17', '363.000']
# ['1938', 'France', 'Italy', 'Hungary', 'Brazil', 'Sweden', '84', '15', '18', '375.700']
# ['1950', 'Brazil', 'Uruguay', 'Brazil', 'Sweden', 'Spain', '88', '13', '22', '1.045.246']
# ['1954', 'Switzerland', 'Germany FR', 'Hungary', 'Austria', 'Uruguay', '140', '16', '26', '768.607']
# ['1958', 'Sweden', 'Brazil', 'Sweden', 'France', 'Germany FR', '126', '16', '35', '819.810']
# ['1962', 'Chile', 'Brazil', 'Czechoslovakia', 'Chile', 'Yugoslavia', '89', '16', '32', '893.172']
# ['1966', 'England', 'England', 'Germany FR', 'Portugal', 'Soviet Union', '89', '16', '32', '1.563.135']
# ['1970', 'Mexico', 'Brazil', 'Italy', 'Germany FR', 'Uruguay', '95', '16', '32', '1.603.975']
# ['1974', 'Germany', 'Germany FR', 'Netherlands', 'Poland', 'Brazil', '97', '16', '38', '1.865.753']
# ['1978', 'Argentina', 'Argentina', 'Netherlands', 'Brazil', 'Italy', '102', '16', '38', '1.545.791']
# ['1982', 'Spain', 'Italy', 'Germany FR', 'Poland', 'France', '146', '24', '52', '2.109.723']
# ['1986', 'Mexico', 'Argentina', 'Germany FR', 'France', 'Belgium', '132', '24', '52', '2.394.031']
# ['1990', 'Italy', 'Germany FR', 'Argentina', 'Italy', 'England', '115', '24', '52', '2.516.215']
# ['1994', 'USA', 'Brazil', 'Italy', 'Sweden', 'Bulgaria', '141', '24', '52', '3.587.538']
# ['1998', 'France', 'France', 'Brazil', 'Croatia', 'Netherlands', '171', '32', '64', '2.785.100']
# ['2002', 'Korea/Japan', 'Brazil', 'Germany', 'Turkey', 'Korea Republic', '161', '32', '64', '2.705.197']
# ['2006', 'Germany', 'Italy', 'France', 'Germany', 'Portugal', '147', '32', '64', '3.359.439']
# ['2010', 'South Africa', 'Spain', 'Netherlands', 'Germany', 'Uruguay', '145', '32', '64', '3.178.856']
# ['2014', 'Brazil', 'Germany', 'Argentina', 'Netherlands', 'Brazil', '171', '32', '64', '3.386.810']
# Total de gols: 2379
# Total de Partidas: 836
# média de gols por partida: 2.85
# Soma de publico nas copas final 0: 0
# Gols total entre 1954 e 1990: 0

# %% [markdown]
# # Resposta

# %% [markdown]
# Soma de público das copas com final 0: 8934841
# Quantidade total de gols entre as copas de 1954 e 1990: 1131
# Média de público: 1872882.35
# Média de gols por partida: 2.85
# Quantidade de vezes em que o país sede foi campeão: 5
# Quantidade de vezes em que o time do Brasil ficou entre uma das 4 primeiras posições: 11
# Ano das edições em que o time da França finalizou em terceiro lugar: 1958, 1986
# Quantidade de vitórias por país, classificada em ordem crescente do número de títulos:
# * England:1
# * France:1
# * Spain:1
# * Germany:1
# * Uruguay:2
# * Argentina:2
# * Germany FR:3
# * Italy:4
# * Brazil:5

# %%
# Resolução e Resposta Aqui
import csv #importa a biblioteca


publicofinal0 = 0
golstotal5490 = 0
publicototal = 0
golstotal = 0
quantidadecopas = 0
totalpartidas = 0
sedecampeao = 0
brasil4 = 0
franca3 = 0



with open('G:/Meu Drive/jupyter/Aulas CDS/FUNDAMENTOS DA PROGRAMAÇÃO/aula_03/csv/world_cups.csv') as file:
    reader= csv.reader(file, delimiter=",")
    next(reader) # pular cabeçalho

print(file)
# Out:
# <_io.TextIOWrapper name='G:/Meu Drive/jupyter/Aulas CDS/FUNDAMENTOS DA PROGRAMAÇÃO/aula_03/csv/world_cups.csv' mode='r' encoding='cp1252'>
