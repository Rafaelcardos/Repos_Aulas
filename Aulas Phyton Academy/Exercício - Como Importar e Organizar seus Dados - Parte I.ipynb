# %% [markdown]
# ## Como Importar e Organizar seus Dados - Parte I

# %% [markdown]
# * Seguem as respostas sugeridas (geralmente, existem várias maneiras de resolver um problema em Python). *

# %% [markdown]
#  A. (* Desafio! *) Crie um objeto de série de 10 valores inteiros gerados aleatoriamente.

# %%
import pandas as pd
import numpy as np

# %%
serie = (np.random.randint(0,100,(1,10)))
serie
# Out:
# array([[12, 65, 34, 97, 88, 94, 19, 92, 36, 57]])

# %% [markdown]
# B. Extraia os dados da yahoo para a Vale S.A. de 1º de janeiro de 2015 até o dia atual. O ticker de que você precisa é ‘VALE3.SA’.

# %%
import pandas_datareader
from pandas_datareader import data as wb
OI = wb.dataReader('VALE3.SA', data_source = 'yahoo', start = '2020-1-1')
OI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4416/4250564871.py in <module>
#       1 import pandas_datareader
#       2 from pandas_datareader import data as wb
# ----> 3 OI = wb.dataReader('VALE3.SA', data_source = 'yahoo', start = '2020-1-1')
#       4 OI
#
# AttributeError: module 'pandas_datareader.data' has no attribute 'dataReader'

# %%
Vale = wb.DataReader('VALE3.SA', data_source='yahoo', start='2015-1-1')
Vale
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  21.950001  21.059999  21.700001  21.280001   5658400.0  14.141930
# 2015-01-05  21.129999  20.510000  20.760000  20.959999   8603000.0  13.929264
# 2015-01-06  22.129999  21.070000  21.070000  21.799999   9879900.0  14.487502
# 2015-01-07  22.809999  21.969999  22.320000  22.600000   6130900.0  15.019152
# 2015-01-08  22.879999  22.110001  22.770000  22.840000   4667300.0  15.178643
# ...               ...        ...        ...        ...         ...        ...
# 2022-03-25  98.300003  94.300003  97.699997  95.230003  22505500.0  95.230003
# 2022-03-28  96.339996  93.610001  95.699997  95.339996  16274200.0  95.339996
# 2022-03-29  95.660004  93.400002  95.339996  94.519997  38228800.0  94.519997
# 2022-03-30  97.110001  95.269997  96.320000  95.870003  22007500.0  95.870003
# 2022-03-31   0.000000   0.000000   0.000000  95.599998         0.0  95.599998
#
# [1800 rows x 6 columns]

# %%
# !PIP install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\rafael\python\lib\site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: requests>=2.26 in c:\users\rafael\python\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\rafael\python\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\rafael\python\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rafael\python\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rafael\python\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\rafael\python\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafael\python\lib\site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rafael\python\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rafael\python\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafael\python\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=cadf333bcae3bad4b8ece15831de0e11095280bc3083bc40f67d1de6da281d10
#   Stored in directory: c:\users\rafael\appdata\local\pip\cache\wheels\f2\b5\2c\59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.10 yfinance-0.1.70

# %%
import yfinance as yf
import pandas_datareader
from pandas_datareader import data as wb
yf.pdr_override ()

import pandas_datareader
from pandas_datareader import data as wb
OI = wb.dataReader('VALE3.SA', data_source = 'yahoo', start = '2020-1-1')
OI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4416/107319018.py in <module>
#       5 import pandas_datareader
#       6 from pandas_datareader import data as wb
# ----> 7 OI = wb.dataReader('VALE3.SA', data_source = 'yahoo', start = '2020-1-1')
#       8 OI
#
# AttributeError: module 'pandas_datareader.data' has no attribute 'dataReader'
