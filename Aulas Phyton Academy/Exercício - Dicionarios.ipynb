# %% [markdown]
# ## Dicionários

# %% [markdown]
# Seguem as respostas sugeridas (geralmente existem várias maneiras de resolver um problema em Python).

# %% [markdown]
# Este é o menu de um restaurante próximo:

# %%
Menu = {'prato_1':'macarrão', 'prato_2':'salada', 'prato_3':'Hamburger', 'prato_4':'peixe'}

# %% [markdown]
# Qual é a segunda refeição da lista?

# %%
Menu['prato_2']
# Out:
# 'salada'

# %% [markdown]
# ou:

# %%
print(Menu['prato_2'])
# Out:
# salada

# %% [markdown]
# Adicione uma nova refeição - "frango".

# %%
Menu['prato_5']='strogonoff'
Menu
# Out:
# {'prato_1': 'macarrão',
#  'prato_2': 'salada',
#  'prato_3': 'Hamburger',
#  'prato_4': 'peixe',
#  'prato_5': 'strogonoff'}

# %% [markdown]
# Substitua o hambúrguer por um omelete.

# %%
Menu['prato_3']='omelete'
Menu
# Out:
# {'prato_1': 'macarrão',
#  'prato_2': 'salada',
#  'prato_3': 'omelete',
#  'prato_4': 'peixe',
#  'prato_5': 'strogonoff'}

# %% [markdown]
# Anexe a lista de sobremesas na forma de uma sexta refeição.

# %%
sobremesas = ['caqui','sagu']

Menu['sobremesas']=sobremesas
Menu
# Out:
# {'prato_1': 'macarrão',
#  'prato_2': 'salada',
#  'prato_3': 'omelete',
#  'prato_4': 'peixe',
#  'prato_5': 'strogonoff',
#  'sobremesas': ['caqui', 'sagu']}

# %% [markdown]
# Crie um novo dicionário que contenha as cinco primeiras refeições como chaves e atribua os seguintes cinco valores como preços (em reais): 10, 5, 8, 12, 5. Comece por lista_de_preço = {}.

# %%
listapreco = {}
listapreco['macarrao']= 10
listapreco['salada']= 5
listapreco['omelete']= 8
listapreco['sarsicha']= 12
listapreco['bife']= 7
listapreco
# Out:
# {'macarrao': 10, 'salada': 5, 'omelete': 8, 'sarsicha': 12, 'bife': 7}

# %% [markdown]
# ou:

# %%
listapreco.get('bife')
# Out:
# 7

# %% [markdown]
# Use o método .get () para verificar o preço do omelete.

# %% [markdown]
# ou:

# %%
print(listapreco.get('bife'))
# Out:
# 7
