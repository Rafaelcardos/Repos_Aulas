# %% [markdown]
# ## Números Aleatórios

# %% [markdown]
# * Seguem as respostas sugeridas (geralmente, existem várias maneiras de resolver um problema em Python). *

# %% [markdown]
# Importe o módulo aleatório e gere uma probabilidade aleatória.

# %%
import random as rd

# %%
p = rd.random()
print(p)
# Out:
# 0.4206786770037918

# %% [markdown]
# Em seguida, gere um número inteiro aleatório no intervalo de 1 a 40.

# %%
ni = rd.randint(1,41)
print(ni)
# Out:
# 21

# %% [markdown]
# Por fim, importe NumPy e crie uma matriz 3 x 5-dimensional, preenchida com inteiros aleatórios dentro do intervalo de 1 e 40.

# %%
import numpy as np

# %%
np.random.randint(1,41,(12,6))
# Out:
# array([[32, 14, 27, 21, 38, 39],
#        [33,  7, 35, 30, 20, 12],
#        [32,  9, 18, 34, 34,  7],
#        [ 4, 25, 36, 25, 13, 11],
#        [21, 26,  3, 38, 29, 31],
#        [14,  7, 33, 30, 18,  3],
#        [16, 10, 19, 39,  4, 23],
#        [ 9, 33, 39, 23, 34, 33],
#        [32, 33,  9,  3, 22,  4],
#        [13, 19, 29,  8, 40,  5],
#        [34, 26, 22, 22,  6, 20],
#        [ 3, 22, 24,  3, 18, 14]])

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: lxml in c:\users\rafael\python\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rafael\python\lib\site-packages (from pandas_datareader) (2.26.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\rafael\python\lib\site-packages (from pandas_datareader) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rafael\python\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rafael\python\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rafael\python\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rafael\python\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafael\python\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafael\python\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rafael\python\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rafael\python\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.7)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
