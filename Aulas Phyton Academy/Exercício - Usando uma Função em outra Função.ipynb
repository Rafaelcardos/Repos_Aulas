# %% [markdown]
# ## Usando uma Função em Outra Função

# %% [markdown]
# Seguem as respostas sugeridas (geralmente existem várias maneiras de resolver um problema em Python).

# %% [markdown]
# Defina uma função que adiciona 5 ao parâmetro. Em seguida, defina outra função que multiplicará o número recém-obtido por 10. Verifique se o seu código estava correto chamando a segunda função com um argumento de 2. Sua saída foi igual a 70?

# %%
def funcaoum(x):
    return x+5
def funcaodois(x):
    return funcaoum(x)*10

# %%
funcaodois(10)
# Out:
# 150

# %%
x = int(input('Coloque aqui a quantidade de horas trabalhadas por dia: '))
hrs_trab = x
salario = hrs_trab * 40
if hrs_trab >= 8:
    bonus = salario + 50
elif hrs_trab < 8:
    bonus = 0
print (bonus)
diario = bonus 
salatot = (bonus - 15) * 25
print(salatot)
# Out:
# Coloque aqui a quantidade de horas trabalhadas por dia: 8
# 370
# 8875

# %%
370*25
# Out:
# 9250
