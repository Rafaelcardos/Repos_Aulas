# %%
x = [1,2,3,4,5]

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# xcsefsfdfsd

# %% [markdown]
# sdasda

# %% [markdown]
# sdasdasd

# %%
x = [1,2,3,4,5]

# %%
x = [1,2,3,4,5]

# %% [markdown]
# sdasdasdas
